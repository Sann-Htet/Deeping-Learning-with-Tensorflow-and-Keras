# %%
import tensorflow_probability as tfp
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Dense
from tensorflow.keras import Sequential

plt.rcParams.update({'font.size': 22})
tfd = tfp.distributions
# Out:
# 2023-09-07 18:09:51.562736: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-09-07 18:09:51.605375: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-09-07 18:09:51.606065: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-07 18:09:52.570954: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
def create_dataset(n, x_range):
    x_uniform_dist = tfd.Uniform(low=x_range[0], high=x_range[1])
    x = x_uniform_dist.sample(n).numpy() [:, np.newaxis] 
    y_true = 2.7*x+3
    eps_uniform_dist = tfd.Normal(loc=0, scale=1)
    eps = eps_uniform_dist.sample(n).numpy() [:, np.newaxis] *0.74*x
    y = y_true + eps
    return x, y, y_true

# %%
x_train, y_train, y_true = create_dataset(200, [-10, 10])
x_val, y_val, _ = create_dataset(50, [-10, 10])
# Out:
# 2023-09-07 18:10:06.467623: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1960] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
def posterior_mean_field(kernel_size, bias_size=0, dtype=None):
    n = kernel_size + bias_size
    c = np.log(np.expm1(1.))
    return Sequential([
        tfp.layers.VariableLayer(2 * n, dtype=dtype),
        tfp.layers.DistributionLambda(lambda t: tfd.Independent(
            tfd.Normal(loc=t[..., :n],
                       scale=1e-5 + tf.nn.softplus(c + t[..., n:])),
            reinterpreted_batch_ndims=1)),
    ])

# %%
def prior_trainable(kernel_size, bias_size=0, dtype=None):
    n = kernel_size + bias_size
    return Sequential([
        tfp.layers.VariableLayer(n, dtype=dtype),
        tfp.layers.DistributionLambda(lambda t: tfd.Independent(
            tfd.Normal(loc=t, scale=1),
            reinterpreted_batch_ndims=1)),
    ])

# %%
negloglik = lambda y, rv_y: -rv_y.log_prob(y)

# %%
# Build model.
model = Sequential([
  tfp.layers.DenseVariational(1, posterior_mean_field, prior_trainable, kl_weight=1/x_train.shape[0]),
  tfp.layers.DistributionLambda(lambda t: tfd.Normal(loc=t, scale=1)),
])

# Do inference.
model.compile(optimizer=tf.optimizers.Adam(learning_rate=0.01), loss=negloglik)
model.fit(x_train, y_train, epochs=100, verbose=1)
# Out:
# Epoch 1/100
# 7/7 [==============================] - 1s 1ms/step - loss: 201.2902
# Epoch 2/100
# 7/7 [==============================] - 0s 1ms/step - loss: 158.7832
# Epoch 3/100
# 7/7 [==============================] - 0s 1ms/step - loss: 113.6760
# Epoch 4/100
# 7/7 [==============================] - 0s 1ms/step - loss: 142.7762
# Epoch 5/100
# 7/7 [==============================] - 0s 1ms/step - loss: 147.4759
# Epoch 6/100
# 7/7 [==============================] - 0s 1ms/step - loss: 186.6067
# Epoch 7/100
# 7/7 [==============================] - 0s 1ms/step - loss: 109.9239
# Epoch 8/100
# 7/7 [==============================] - 0s 1ms/step - loss: 130.5636
# Epoch 9/100
# 7/7 [==============================] - 0s 1ms/step - loss: 159.5526
# Epoch 10/100
# 7/7 [==============================] - 0s 1ms/step - loss: 75.6451
# Epoch 11/100
# 7/7 [==============================] - 0s 1ms/step - loss: 99.8076
# Epoch 12/100
# 7/7 [==============================] - 0s 1ms/step - loss: 83.4421
# Epoch 13/100
# 7/7 [==============================] - 0s 1ms/step - loss: 86.9477
# Epoch 14/100
# 7/7 [==============================] - 0s 1ms/step - loss: 69.4561
# Epoch 15/100
# 7/7 [==============================] - 0s 1ms/step - loss: 76.6993
# Epoch 16/100
# 7/7 [==============================] - 0s 1ms/step - loss: 66.6819
# Epoch 17/100
# 7/7 [==============================] - 0s 1ms/step - loss: 73.9728
# Epoch 18/100
# 7/7 [==============================] - 0s 1ms/step - loss: 90.8723
# Epoch 19/100
# 7/7 [==============================] - 0s 1ms/step - loss: 71.4358
# Epoch 20/100
# 7/7 [==============================] - 0s 1ms/step - loss: 57.2134
# Epoch 21/100
# 7/7 [==============================] - 0s 1ms/step - loss: 59.5341
100
# 7/7 [==============================] - 0s 1ms/step - loss: 17.2196
# Epoch 58/100
# 7/7 [==============================] - 0s 1ms/step - loss: 16.5114
# Epoch 59/100
# 7/7 [==============================] - 0s 1ms/step - loss: 19.7780
# Epoch 60/100
# 7/7 [==============================] - 0s 1ms/step - loss: 21.0927
# Epoch 61/100
# 7/7 [==============================] - 0s 1ms/step - loss: 19.3657
# Epoch 62/100
# 7/7 [==============================] - 0s 1ms/step - loss: 16.8495
# Epoch 63/100
# 7/7 [==============================] - 0s 1ms/step - loss: 17.9232
# Epoch 64/100
# 7/7 [==============================] - 0s 1ms/step - loss: 16.7237
# Epoch 65/100
# 7/7 [==============================] - 0s 1ms/step - loss: 19.6704
# Epoch 66/100
# 7/7 [==============================] - 0s 1ms/step - loss: 14.2338
# Epoch 67/100
# 7/7 [==============================] - 0s 1ms/step - loss: 17.0119
# Epoch 68/100
# 7/7 [==============================] - 0s 1ms/step - loss: 14.6773
# Epoch 69/100
# 7/7 [==============================] - 0s 1ms/step - loss: 13.9734
# Epoch 70/100
# 7/7 [==============================] - 0s 3ms/step - loss: 14.9273
# Epoch 71/100
# 7/7 [==============================] - 0s 2ms/step - loss: 15.2286
# Epoch 72/100
# 7/7 [==============================] - 0s 1ms/step - loss: 18.1264
# Epoch 73/100
# 7/7 [==============================] - 0s 1ms/step - loss: 17.0417
# Epoch 74/100
# 7/7 [==============================] - 0s 1ms/step - loss: 14.0562
# Epoch 75/100
# 7/7 [==============================] - 0s 1ms/step - loss: 16.4122
# Epoch 76/100
# 7/7 [==============================] - 0s 1ms/step - loss: 14.2822
# Epoch 77/100
# 7/7 [==============================] - 0s 1ms/step - loss: 13.2149
# Epoch 78/100
# 7/7 [==============================] - 0s 1ms/step - loss: 14.5855
# Epoch 79/100
# 7/7 [==============================] - 0s 1ms/step - loss: 17.8712
# Epoch 80/100
# 7/7 [==============================] - 0s 1ms/step - loss: 16.1970
# Epoch 81/100
# 7/7 [==============================] - 0s 1ms/step - loss: 12.7178
# Epoch 82/100
# 7/7 [==============================] - 0s 1ms/step - loss: 13.1931
# Epoch 83/100
# 7/7 [==============================] - 0s 1ms/step - loss: 12.4916
# Epoch 84/100
# 7/7 [==============================] - 0s 987us/step - loss: 15.0834
# Epoch 85/100
# 7/7 [==============================] - 0s 1ms/step - loss: 11.7320
# Epoch 86/100
# 7/7 [==============================] - 0s 1ms/step - loss: 13.7952
# Epoch 87/100
# 7/7 [==============================] - 0s 1ms/step - loss: 13.1596
# Epoch 88/100
# 7/7 [==============================] - 0s 1ms/step - loss: 15.5840
# Epoch 89/100
# 7/7 [==============================] - 0s 1ms/step - loss: 14.7562
# Epoch 90/100
# 7/7 [==============================] - 0s 1ms/step - loss: 14.0405
# Epoch 91/100
# 7/7 [==============================] - 0s 1ms/step - loss: 13.8960
# Epoch 92/100
# 7/7 [==============================] - 0s 1ms/step - loss: 17.2993
# Epoch 93/100
# 7/7 [==============================] - 0s 1ms/step - loss: 14.4957
# Epoch 94/100
# 7/7 [==============================] - 0s 1ms/step - loss: 13.8756
# Epoch 95/100
# 7/7 [==============================] - 0s 1ms/step - loss: 14.4043
# Epoch 96/100
# 7/7 [==============================] - 0s 1ms/step - loss: 13.2522
# Epoch 97/100
# 7/7 [==============================] - 0s 1ms/step - loss: 12.1774
# Epoch 98/100
# 7/7 [==============================] - 0s 1ms/step - loss: 12.0389
# Epoch 99/100
# 7/7 [==============================] - 0s 1ms/step - loss: 14.8922
# Epoch 100/100
# 7/7 [==============================] - 0s 1ms/step - loss: 13.5442

# %%
x_range = [-10, 10]
plt.figure(figsize=[10, 10]) 
plt.clf();
plt.plot(x_train, y_train, 'b.', label='observed');

y_preds = [model(x_val) for _ in range(100)]
avgm = np.zeros_like(x_val[..., 0])
for i, yhat in enumerate(y_preds):
    m = np.squeeze(yhat.mean())
    s = np.squeeze(yhat.stddev())
    if i < 15:
        plt.plot(x_val, m, 'r', label='ensemble means' if i == 0 else None, linewidth=0.5)
    avgm += m
plt.plot(x_val, avgm/len(y_preds), 'g', label='overall mean', linewidth=4)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.legend(loc='upper left', prop={'size': 20})

# %% [markdown]
# ---
